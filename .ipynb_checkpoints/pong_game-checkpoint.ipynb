# %%
import numpy as np
from env_pong import PongEnv
from models import Baseline
from models import HumanPlayer
from models import DQN_StBaselines3
import stable_baselines3
from stable_baselines3 import DQN

# %%
train_env = PongEnv(render_mode=None, opponent=Baseline(difficult=1))

dqn_left = DQN(
    policy='MlpPolicy',
    env=train_env    
)
dqn_left.learn(600000)
env_test = PongEnv(render_mode='human', opponent=Baseline(difficult=1))

# %%
env_test.demo(n_steps=2000, left_player=DQN_StBaselines3(model=dqn_left))
# Out:
# Эпизод завершён на шаге 191
# Эпизод завершён на шаге 383
# Эпизод завершён на шаге 626
# Эпизод завершён на шаге 1139
# Эпизод завершён на шаге 1357
# Эпизод завершён на шаге 1796

# %%
dqn_left.save("pong_dqn_600k")

# %%
dqn_left.learn(1000000)

# %%
dqn_left.save("pong_dqn_1M")

# %%
env_test.demo(n_steps=3000, left_player=DQN_StBaselines3(model=dqn_left))
# Out:
# Эпизод завершён на шаге 1195
# Эпизод завершён на шаге 1387
# Эпизод завершён на шаге 1757
# Эпизод завершён на шаге 2463

# %%
env_self_test = PongEnv(render_mode='human', opponent=HumanPlayer())
env_self_test.demo(n_steps=4000, left_player=DQN_StBaselines3(model=dqn_left))
# Out:
# Эпизод завершён на шаге 1266
# Эпизод завершён на шаге 1367
# Эпизод завершён на шаге 1882
# Эпизод завершён на шаге 3120
# Эпизод завершён на шаге 3511

# %%
# 1. Загружаем старую модель
old_dqn = DQN.load("pong_dqn_1M")

# 2. Создаем окружение
train_env = PongEnv(render_mode=None, opponent=Baseline(difficult=1))

# 3. Создаем НОВУЮ модель с ТОЙ ЖЕ архитектурой, но другими параметрами
new_dqn = DQN(
    policy='MlpPolicy',
    env=train_env,
    learning_rate=1e-3,
    buffer_size=100000,
    learning_starts=1000,
    batch_size=64,
    tau=1.0,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
    exploration_fraction=0.05,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    policy_kwargs=dict(net_arch=[64, 64]),  # ← ТА ЖЕ архитектура!
)

# 4. Копируем веса (теперь размеры совпадают!)
new_dqn.policy.load_state_dict(old_dqn.policy.state_dict())
print("Веса скопированы!")

# 5. Доучиваем
new_dqn.learn(200000)
new_dqn.save("pong_dqn_1.2M")
# Out:
# Веса скопированы!

# %%
env_self_test = PongEnv(render_mode='human', opponent=HumanPlayer())
env_self_test.demo(n_steps=10000, left_player=DQN_StBaselines3(model=new_dqn))
# Out:
# Эпизод завершён на шаге 516
# Эпизод завершён на шаге 617
# Эпизод завершён на шаге 1134
# Эпизод завершён на шаге 1391
# Эпизод завершён на шаге 1757
# Эпизод завершён на шаге 2441
# Эпизод завершён на шаге 3809
# Эпизод завершён на шаге 3910
# Эпизод завершён на шаге 4321
# Эпизод завершён на шаге 4789
# Эпизод завершён на шаге 4982
# Эпизод завершён на шаге 5273
# Эпизод завершён на шаге 5823
# Эпизод завершён на шаге 6016
# Эпизод завершён на шаге 6460
# Эпизод завершён на шаге 7310
# Эпизод завершён на шаге 7829
# Эпизод завершён на шаге 8668
# Эпизод завершён на шаге 9677

# %%
new_dqn.save("pong_dqn_1.2M.zip")
