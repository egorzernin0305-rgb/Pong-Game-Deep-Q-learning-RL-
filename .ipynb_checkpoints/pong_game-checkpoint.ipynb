# %%
import numpy as np
from env_pong import PongEnv
from models import Baseline
from models import HumanPlayer
from models import DQN_StBaselines3
import stable_baselines3
from stable_baselines3 import DQN

# %%
dqn_best = DQN.load("saved_models/pong_dqn_1.2M.zip")
#env_test = PongEnv(render_mode='human', opponent=HumanPlayer())
#env_test.demo(n_steps=100, left_player=DQN_StBaselines3(model=dqn_best))

# %%
train_env = PongEnv(opponent=Baseline())
new_dqn = DQN(
    policy='MlpPolicy',
    env=train_env,
    learning_rate=1e-4,                     
    buffer_size=100000,
    exploration_fraction=0.03,              
    exploration_final_eps=0.0005,            
    policy_kwargs=dict(net_arch=[64, 64]),  
)
new_dqn.policy.load_state_dict(dqn_best.policy.state_dict())

# %%
#new_dqn.learn(250000) 
#new_dqn.save("pong_dqn_1.45M_uniform_reward.zip")
new_dqn.load("pong_dqn_1.45M_uniform_reward.zip")

# %%
env_test = PongEnv(opponent=Baseline(),  render_mode = 'human')
env_test.demo(n_steps=100000, close_at_end=True)
